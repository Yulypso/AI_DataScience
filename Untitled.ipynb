# %%
import pandas
import matplotlib.pyplot as plt
import seaborn

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"]= 20, 10
import warnings
warnings.filterwarnings('ignore')

# %%
data = pandas.read_csv('C:/Users/Thierry KHAMPHOUSONE/Desktop/Lab1/input/train.csv')

# %%
data.head()  #5premiere ligne montré à l'écran + colonnes
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
target = data['SalePrice']
target.describe() #nombre de données, moyenne, minimum, maximum, variance std, premiere vision des données
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
seaborn.distplot(target) #seaborn pour visualisation de target, et target c'est SalePrice
#distribution régulière, la majorité des maisons vendu son à 130 000€

# %%
#scatter plot grlivarea/saleprice
data.plot.scatter(x='GrLivArea', y='SalePrice', ylim=(0, 800000))
#chaque point représente une maison, prix de vente en fonction de la surface
#on a des données out layer, comme grande surface prxi bas et grande surface prix haut

# %%
seaborn.boxplot(x='YearBuilt', y="SalePrice", data=data)
#minimum, maximum, variance, année par block, pas mal de variabilité avant 1900, et ensuite stabilité vers 1960
#visualisation granulaire

# %%
data['year_grouped'] = pandas.cut(data['YearBuilt'], 10)
seaborn.boxplot(x='year_grouped', y="SalePrice", data=data)
#corrélation légere entre année de construction et prix de la maison

# %%
data['year_grouped'] = pandas.qcut(data['YearBuilt'], 10)
seaborn.boxplot(x='year_grouped', y="SalePrice", data=data)
#réajustement des données, 10 maisons par groupes

# %%
seaborn.distplot(data['YearBuilt'])
#2 guerres donne des constructions, crises pétroiere, cela valide notre connaissance des regles qui peuvent s'appliquer autour de la description des données

# %% [markdown]
# scatter plot grlivarea/saleprice
# data.plot.scatter(x='GrLivArea', y='SalePrice', ylim=(0, 800000))

# %%
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
seaborn.pairplot(data[cols], size = 2.5, plot_kws=dict(s=20))
#pour chacune de ses features, on peut comparer par exemple saleprice et place de parking (garage) : le prix + en fonction du nombre de parking
#ligne : distrib discrete
#points nuées : continues

# %%
from  sklearn.linear_model import LinearRegression #permet de calculer notre modele

# %%
features = ['OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
target = 'SalePrice' 
#création d'un vecteur, et on met en fonction du prix de vente

# %%
features_data = data[features]
target_data = data[target]

# %%
my_first_model = LinearRegression() #régression linéaire créée
my_first_model.fit(features_data, target_data) #notre modèle entrainné avec les datas précédents
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#on va voir mtn si on peut prédire le prix d'une maison en lui ayant donné des caractéristiques particulières
from collections import OrderedDict

# Fill with your house data
my_house = pandas.DataFrame([OrderedDict({'OverallQual': 7, #qualité
                                         'GrLivArea': 150, 
                                         'GarageCars': 2, 
                                         'TotalBsmtSF': 200, 
                                         'FullBath': 1, 
                                         'YearBuilt': 1880})])

# compute your price estimation using your first mode
my_price_estimation = my_first_model.predict(my_house)
print(f'The price estimation of your house is: {my_price_estimation[0] :.2f} $')
# Out:
# The price estimation of your house is: 76348.07 $

# %%
#comment peut on jouer avec ces données là ? 

# Fill with your house data
my_house = pandas.DataFrame([OrderedDict({'OverallQual': 2, #qualité
                                         'GrLivArea': 150, 
                                         'GarageCars': 2, 
                                         'TotalBsmtSF': 200, 
                                         'FullBath': 1, 
                                         'YearBuilt': 1880})])

# compute your price estimation using your first mode
my_price_estimation = my_first_model.predict(my_house)
print(f'The price estimation of your house is: {my_price_estimation[0] :.2f} $')

#la valeur de la qualité influe énormément le prix de revient.
# Out:
# The price estimation of your house is: -26251.78 $

# %%
# Fill with your house data
my_house = pandas.DataFrame([OrderedDict({'OverallQual': 7, #qualité
                                         'GrLivArea': 150, 
                                         'GarageCars': 2, 
                                         'TotalBsmtSF': 200, 
                                         'FullBath': 1, 
                                         'YearBuilt': 1980})])

# compute your price estimation using your first mode
my_price_estimation = my_first_model.predict(my_house)
print(f'The price estimation of your house is: {my_price_estimation[0] :.2f} $')

#on place la date a 1980.
# Out:
# The price estimation of your house is: 110002.74 $

# %%
# Fill with your house data
my_house = pandas.DataFrame([OrderedDict({'OverallQual': 7, #qualité
                                         'GrLivArea': 500, #taille habitable
                                         'GarageCars': 2, 
                                         'TotalBsmtSF': 200, 
                                         'FullBath': 1, 
                                         'YearBuilt': 1980})])

# compute your price estimation using your first mode
my_price_estimation = my_first_model.predict(my_house)
print(f'The price estimation of your house is: {my_price_estimation[0] :.2f} $')

#taille habitable pas trop influent.
# Out:
# The price estimation of your house is: 128929.28 $

# %%
# Fill with your house data
my_house = pandas.DataFrame([OrderedDict({'OverallQual': 7, #qualité
                                         'GrLivArea': 150, 
                                         'GarageCars': 2, 
                                         'TotalBsmtSF': 200, 
                                         'FullBath': 3, 
                                         'YearBuilt': 1980})])

# compute your price estimation using your first mode
my_price_estimation = my_first_model.predict(my_house)
print(f'The price estimation of your house is: {my_price_estimation[0] :.2f} $')

#prix avec 1 salle de bain : 128929 et prix avec 3 salle de bains le prix diminue, surement car la surface est petite pour 3 salle de bains.
# Out:
# The price estimation of your house is: 98994.79 $

# %%
for feature, coef in zip(features, my_first_model.coef_):
    print(f'{feature}: {coef: .2f}')
#la qualité à un impact très important, de 20519
#la surface habitable faible
#nb place parking assez important
#taille de la cave faible
#nombre de salle de bain a une corrélation négative, si on rajoute des salles de bains, on perd le prix de vente
#année de construction qui a un tout petit impact en croissance.
# Out:
# OverallQual:  20519.97
# GrLivArea:  54.08
# GarageCars:  14646.32
# TotalBsmtSF:  29.18
# FullBath: -5503.97
# YearBuilt:  336.55
